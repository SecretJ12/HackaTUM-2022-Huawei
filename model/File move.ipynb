# %%
f = open("labels_val.csv")
import os 
import shutil 

for x in f:
    
    index,label = x.split(",")
    print(index + " " + label)
    os.rename("/home/oliver/coding/py/HackaTUM_Data/dataset/hackatum_dataset/val/"+index+".jpg", "/home/oliver/coding/py/HackaTUM_Data/dataset/hackatum_dataset/val/"+label.rstrip()+"/"+index+".jpg")
# Out:
# 118033853940785 footway
#
# 142360954539412 primary
#
# 151552926945434 primary
#
# 152113683604813 footway
#
# 154972666585450 primary
#
# 165180662274601 footway
#
# 165325312104833 footway
#
# 175153487833042 primary
#
# 176128040978236 primary
#
# 177003250871249 primary
#
# 177970074196189 primary
#
# 188898393089879 primary
#
# 194729679139646 primary
#
# 205585951391226 primary
#
# 206690207942627 footway
#
# 206818761057187 footway
#
# 217880619798407 primary
#
# 221748706052474 primary
#
# 231548545020391 footway
#
# 234764851740534 primary
#
# 256926566182023 primary
#
# 257384076307663 primary
#
# 262827108876163 primary
#
# 272074997915992 primary
#
# 279051850575007 footway
#
# 288933689555335 footway
#
# 295323455475976 primary
#
# 295819725538065 primary
#
# 300768428155320 primary
#
# 302170867952786 footway
#
# 303854877900068 primary
#
# 307197161069899 footway
#
# 307614427624140 primary
#
# 312326340551902 primary
#
# 322976835868405 footway
#
# ...

# %%
# Out:
# 102065035753324,footway
#
# 114536350969969,footway
#
# 119878327096719,footway
#
# 120800660045235,footway
#
# 122842090396633,primary
#
# 127739299378376,primary
#
# 130568772443246,primary
#
# 135355468611603,primary
#
# 135692471920408,primary
#
# 137333565000984,primary
#
# 138172478330955,primary
#
# 138657528252576,footway
#
# 140152694749643,primary
#
# 140498938006301,primary
#
# 143168501126108,primary
#
# 144171024302339,primary
#
# 145130154198250,footway
#
# 146654997441360,footway
#
# 147929920648966,primary
#
# 151225416969648,footway
#
# 152298047204936,footway
#
# 152566850161683,footway
#
# 153221476822862,footway
#
# 154712939997167,primary
#
# 155205536612299,primary
#
# 155751886432795,primary
#
# 155884206867608,footway
#
# 156737736411618,footway
#
# 157310776724638,footway
#
# 157582279614181,primary
#
# 159874669420040,footway
#
# 160224679370381,primary
#
# 165967342101635,primary
#
# 169017638459100,primary
#
# 169529718448529,footway
#
# ...

# %%
f.close()
